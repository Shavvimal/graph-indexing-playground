# %%
# Copyright (c) 2024 Microsoft Corporation.
# Licensed under the MIT License.

# %%
import os

import pandas as pd
import tiktoken

from graphrag.query.context_builder.entity_extraction import EntityVectorStoreKey
from graphrag.query.indexer_adapters import (
    read_indexer_covariates,
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.query.input.loaders.dfs import (
    store_entity_semantic_embeddings,
)
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.embedding import OpenAIEmbedding
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.question_gen.local_gen import LocalQuestionGen
from graphrag.query.structured_search.local_search.mixed_context import (
    LocalSearchMixedContext,
)
from graphrag.query.structured_search.local_search.search import LocalSearch
from graphrag.vector_stores.lancedb import LanceDBVectorStore
from dotenv import load_dotenv

_ = load_dotenv()

# %% [markdown]
# ## Local Search Example
#
# Local search method generates answers by combining relevant data from the AI-extracted knowledge-graph with text chunks of the raw documents. This method is suitable for questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?).

# %% [markdown]
# ### Load text units and graph data tables as context for local search
#
# - In this test we first load indexing outputs from parquet files to dataframes, then convert these dataframes into collections of data objects aligning with the knowledge model.

# %% [markdown]
# ### Load tables to dataframes

# %%
FOLDER = "20240903-181408"
INPUT_DIR = f"../bin/output/{FOLDER}/artifacts" 
LANCEDB_URI = f"{INPUT_DIR}/lancedb"

COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"
RELATIONSHIP_TABLE = "create_final_relationships"
COVARIATE_TABLE = "create_final_covariates"
TEXT_UNIT_TABLE = "create_final_text_units"
COMMUNITY_LEVEL = 2

# %% [markdown]
# #### Read entities

# %%
# read nodes table to get community and degree data
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)

# load description embeddings to an in-memory lancedb vectorstore
# to connect to a remote db, specify url and port values.
description_embedding_store = LanceDBVectorStore(
    collection_name="entity_description_embeddings",
)
description_embedding_store.connect(db_uri=LANCEDB_URI)
entity_description_embeddings = store_entity_semantic_embeddings(
    entities=entities, vectorstore=description_embedding_store
)

print(f"Entity count: {len(entity_df)}")
entity_df.head()
# Out:
# Entity count: 6344
#    level                title        type  \
# 0      0               MARKET      MARKET
# 1      0             BUSINESS     COMPANY
# 2      0  PRODUCT DEVELOPMENT     PRODUCT
# 3      0                PITCH       PITCH
# 4      0            INVESTORS  INVESTMENT
#
#                                          description  \
# 0  The "MARKET" is the arena of commercial dealin...
# 1  A **BUSINESS** is a commercial entity that aim...
# 2  PRODUCT DEVELOPMENT is the process of creating...
# 3  "PITCH" is a structured presentation or speech...
# 4  **INVESTORS** are individuals or entities that...
#
#                                            source_id community  degree  \
# 0  01f8ac021603c0416588ca16b8e25f91,0c43e8f182247...         5      48
# 1  20642aed7debb52ac6a1fbb51c1d37cb,5044305935cc2...        25      26
# 2  01f8ac021603c0416588ca16b8e25f91,20642aed7debb...        25       4
# 3  20642aed7debb52ac6a1fbb51c1d37cb,2186a012e56a7...         5      21
# 4  01f8ac021603c0416588ca16b8e25f91,07aa3332020a5...        28      43
#
#    human_readable_id                                id  size  \
# 0                  0  b45241d70f0e43fca764df95b2b81f77    48
# 1                  1  4119fd06010c494caa07f439b333f4c5    26
# 2                  2  d3835bf3dda84ead99deadbeac5d0d7d     4
# 3                  3  077d2820ae1845bcbb1803379a3d1eae    21
# 4                  4  3671ea0dd4e84c1a9b02c5ab2c8f4bac    43
#
#                                      graph_embedding entity_type  \
# 0  [0.07086440175771713, -0.0688755065202713, -0....        None
# 1  [0.014605529606342316, -0.004586625378578901, ...        None
# 2  [0.057798705995082855, 0.06357988715171814, -0...        None
# 3  [-0.11226696521043777, 0.015231314115226269, 0...        None
# 4  [-0.09893009066581726, 0.068280428647995, -0.0...        None
#
#                   top_level_node_id  x  y
# 0  b45241d70f0e43fca764df95b2b81f77  0  0
# 1  4119fd06010c494caa07f439b333f4c5  0  0
# 2  d3835bf3dda84ead99deadbeac5d0d7d  0  0
# 3  077d2820ae1845bcbb1803379a3d1eae  0  0
# 4  3671ea0dd4e84c1a9b02c5ab2c8f4bac  0  0

# %% [markdown]
# #### Read relationships

# %%
relationship_df = pd.read_parquet(f"{INPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")
relationships = read_indexer_relationships(relationship_df)

print(f"Relationship count: {len(relationship_df)}")
relationship_df.head()
# Out:
# Relationship count: 2226
#    source                          target  weight  \
# 0  MARKET                        BUSINESS     2.0
# 1  MARKET    ANALYSIS AND RESEARCH ONLINE     1.0
# 2  MARKET  TALK TO PEOPLE IN THE INDUSTRY     1.0
# 3  MARKET           MARKET RESEARCH TOOLS     1.0
# 4  MARKET              PRODUCT CATEGORIES     1.0
#
#                                          description  \
# 0  A business operates within a market to sell it...
# 1  Analysis and research online help understand t...
# 2  Talking to industry veterans or consultants he...
# 3  Market research tools help analyze various asp...
# 4  Product categories are part of the overall mar...
#
#                                        text_unit_ids  \
# 0  [20642aed7debb52ac6a1fbb51c1d37cb, 91268bea004...
# 1                 [3b59766cf7ab030a10e237fc8af3b657]
# 2                 [3b59766cf7ab030a10e237fc8af3b657]
# 3                 [3b59766cf7ab030a10e237fc8af3b657]
# 4                 [3b59766cf7ab030a10e237fc8af3b657]
#
#                                  id human_readable_id  source_degree  \
# 0  32d785e275be458fb7178ad2021ecdfc                 0             48
# 1  0757f97d1fbf49748169ba696a364e4c                 1             48
# 2  ca9a355bf38b452cbde62dba747ec65f                 2             48
# 3  ba297c67512447e4b86f0cbc39fbc301                 3             48
# 4  00a9c8745b404b659c76a694dba9851c                 4             48
#
#    target_degree  rank
# 0             26    74
# 1              1    49
# 2              2    50
# 3              2    50
# 4              1    49

# %%
# NOTE: covariates are turned off by default, because they generally need prompt tuning to be valuable
# Please see the GRAPHRAG_CLAIM_* settings
covariate_df = pd.read_parquet(f"{INPUT_DIR}/{COVARIATE_TABLE}.parquet")

claims = read_indexer_covariates(covariate_df)

print(f"Claim records: {len(claims)}")
covariates = {"claims": claims}
# Out:
# Claim records: 327

# %%
covariate_df
# Out:
#                                        id human_readable_id covariate_type  \
# 0    6aefddc9-e00e-495e-bb20-c564836405bc                 1          claim
# 1    147a20ac-8ceb-4a60-9358-a096c5f32abb                 2          claim
# 2    d479df17-7be5-4618-9a14-cb189ea81c10                 3          claim
# 3    3ca907d6-0132-4610-a386-1f1f3c07a3c5                 4          claim
# 4    70f83dbd-953b-4884-b46e-be23deb230d4                 5          claim
# ..                                    ...               ...            ...
# 322  8fd685b4-b4ec-4b3b-b238-109b2273af15               323          claim
# 323  0ce9d707-d368-4f13-9de8-836c4c3d9bc4               324          claim
# 324  dd54ad22-7e5e-4c95-b784-e9ade5b5a94d               325          claim
# 325  08acf124-e6cc-4110-8f4a-ab65ddc93da6               326          claim
# 326  9bbbeecf-838c-433f-9846-7247a6884665               327          claim
#
#                          type  \
# 0                        None
# 1      SUCCESSFUL PROPOSITION
# 2                        None
# 3                        None
# 4                        None
# ..                        ...
# 322      SUCCESSFUL D2C BRAND
# 323        DISRUPTIVE COMPANY
# 324                      None
# 325  MENTORSHIP OPPORTUNITIES
# 326           GLOBAL PRESENCE
#
#                                            description  \
# 0                                                 None
# 1    Facebook had a successful proposition early in...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 322  The Honest Company, founded by Jessica Alba, f...
# 323  Uber is a hugely disruptive company that has p...
# 324                                               None
# 325  Antler provides mentorship, networking, and VC...
# 326  Antler is available in 25 cities around the wo...
#
#                                             subject_id subject_type  \
# 0                                                              None
# 1                                             FACEBOOK         None
# 2    There are no named entities that match the pre...         None
# 3                                                              None
# 4                                                              None
# ..                                                 ...          ...
# 322                                 THE HONEST COMPANY         None
# 323                                               UBER         None
# 324                                                            None
# 325                                             ANTLER         None
# 326                                             ANTLER         None
#
#      object_id object_type status start_date end_date  \
# 0         None        None   None       None     None
# 1    INVESTORS        None   TRUE       NONE     NONE
# 2         None        None   None       None     None
# 3         None        None   None       None     None
# 4         None        None   None       None     None
# ..         ...         ...    ...        ...      ...
# 322       NONE        None   TRUE       NONE     NONE
# 323       NONE        None   TRUE       NONE     NONE
# 324       None        None   None       None     None
# 325       NONE        None   TRUE       NONE     NONE
# 326       NONE        None   TRUE       NONE     NONE
#
#                                            source_text  \
# 0                                                 None
# 1    Without Facebook having such a successful prop...
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 322  If you’ve ever wondered where Jessica Alba tur...
# 323  Everyone knows that Uber is a hugely disruptiv...
# 324                                               None
# 325  The mentorship, networking and VC funding oppo...
# 326  itâs [available in 25 cities around the worl...
#
#                          text_unit_id                document_ids  n_tokens
# 0    20642aed7debb52ac6a1fbb51c1d37cb  [66d616da48ddb30febdf69d0]      1200
# 1    20642aed7debb52ac6a1fbb51c1d37cb  [66d616da48ddb30febdf69d0]      1200
# 2    b10026f1630f7cfc6a45f11b08542343  [66d616da48ddb30febdf69d0]      1200
# 3    198cc9c7876047173850cf0fbd262fd5  [66d616da48ddb30febdf69d0]      1200
# 4    3b59766cf7ab030a10e237fc8af3b657  [66d616da48ddb30febdf69d0]       463
# ..                                ...                         ...       ...
# 322  83ab2fad3c97c23e719e3b703d33982c  [66d616e048ddb30febdf69f5]      1155
# 323  83ab2fad3c97c23e719e3b703d33982c  [66d616e048ddb30febdf69f5]      1155
# 324  72d5c68cc70917432e845486770e8523  [66d616e048ddb30febdf69f5]        55
# 325  72d5c68cc70917432e845486770e8523  [66d616e048ddb30febdf69f5]        55
# 326  72d5c68cc70917432e845486770e8523  [66d616e048ddb30febdf69f5]        55
#
# [327 rows x 16 columns]

# %% [markdown]
# #### Read community reports

# %%
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)

print(f"Report records: {len(report_df)}")
report_df.head()
# Out:
# Report records: 297
# Z:\code\007\graphrag-pipeline\graphrag\query\indexer_adapters.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entity_df["community"] = entity_df["community"].fillna(-1)
# Z:\code\007\graphrag-pipeline\graphrag\query\indexer_adapters.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entity_df["community"] = entity_df["community"].astype(int)
#   community                                       full_content  level  rank  \
# 0       293  # MVP and Pre-Seed Investors in Startup Ecosys...      3   9.0
# 1       294  # Early Adopters and Marketing Strategy in Sta...      3   9.0
# 2       295  # Pricing Strategy and Competitive Landscape i...      3   9.0
# 3       296  # Subscription Revenue Model and Recurring Rev...      3   9.0
# 4       159  # AXE and the #PraiseUp Campaign\n\nThe commun...      2   9.0
#
#                                                title  \
# 0   MVP and Pre-Seed Investors in Startup Ecosystems
# 1  Early Adopters and Marketing Strategy in Start...
# 2  Pricing Strategy and Competitive Landscape in ...
# 3   Subscription Revenue Model and Recurring Revenue
# 4                     AXE and the #PraiseUp Campaign
#
#                                     rank_explanation  \
# 0  The rating is high due to the critical role of...
# 1  The rating is high due to the significant impa...
# 2  The rating is high due to the significant impa...
# 3  The rating is high due to the significant impa...
# 4  The rating is high due to the significant impa...
#
#                                              summary  \
# 0  The community revolves around the development ...
# 1  The community revolves around the critical rol...
# 2  The community revolves around the critical ele...
# 3  The community revolves around the Subscription...
# 4  The community revolves around AXE and its #Pra...
#
#                                             findings  \
# 0  [{'explanation': 'The Minimum Viable Product (...
# 1  [{'explanation': 'Early adopters are pivotal i...
# 2  [{'explanation': 'Pricing strategy is a fundam...
# 3  [{'explanation': 'The Subscription Revenue Mod...
# 4  [{'explanation': 'AXE has demonstrated a highl...
#
#                                    full_content_json  \
# 0  {\n    "title": "MVP and Pre-Seed Investors in...
# 1  {\n    "title": "Early Adopters and Marketing ...
# 2  {\n    "title": "Pricing Strategy and Competit...
# 3  {\n    "title": "Subscription Revenue Model an...
# 4  {\n    "title": "AXE and the #PraiseUp Campaig...
#
#                                      id
# 0  cb068c41-6437-4381-9e3f-a4ce4a4e1361
# 1  48490d91-e49b-4e3a-93ad-c37e03355889
# 2  1d8ac395-f047-4291-a929-bdc8c39bb817
# 3  275dc09b-f490-4ae8-bacf-2d884f440814
# 4  78ad3323-9456-4bdf-bad4-0d7bb8322227

# %% [markdown]
# #### Read text units

# %%
text_unit_df = pd.read_parquet(f"{INPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

print(f"Text unit records: {len(text_unit_df)}")
text_unit_df.head()
# Out:
# Text unit records: 127
#                                  id  \
# 0  20642aed7debb52ac6a1fbb51c1d37cb
# 1  b10026f1630f7cfc6a45f11b08542343
# 2  198cc9c7876047173850cf0fbd262fd5
# 3  3b59766cf7ab030a10e237fc8af3b657
# 4  b4e3a5127b17e2d9ecc232f9491d5d45
#
#                                                 text  n_tokens  \
# 0  # TAM, SAM & SOM: How To Calculate The Size Of...      1200
# 1   its TAM,\nbut few startups would want to dedi...      1200
# 2  love a âGoldilocksâ business, as far as th...      1200
# 3   their own business will fit in.\n\n### **1) A...       463
# 4  # Unicorn Companies Explained: How Startups Ac...      1200
#
#                  document_ids  \
# 0  [66d616da48ddb30febdf69d0]
# 1  [66d616da48ddb30febdf69d0]
# 2  [66d616da48ddb30febdf69d0]
# 3  [66d616da48ddb30febdf69d0]
# 4  [66d616da48ddb30febdf69d1]
#
#                                           entity_ids  \
# 0  [b45241d70f0e43fca764df95b2b81f77, 4119fd06010...
# 1  [077d2820ae1845bcbb1803379a3d1eae, 1fd3fa8bb5a...
# 2  [3671ea0dd4e84c1a9b02c5ab2c8f4bac, 19a7f254a5d...
# 3  [b45241d70f0e43fca764df95b2b81f77, 19a7f254a5d...
# 4  [1fd3fa8bb5a2408790042ab9573779ee, bf4e255cdac...
#
#                                     relationship_ids  \
# 0  [32d785e275be458fb7178ad2021ecdfc, 00cb0db6e46...
# 1  [20be7b3222174d31839fac6a278f8b61, 35688e258b0...
# 2  [9a27717e1a1b499981031fd69c58aff1, 4efbe8fc23a...
# 3  [0757f97d1fbf49748169ba696a364e4c, ca9a355bf38...
# 4  [e7ac741e4aa4433ca5f2379726f90b33, 43645eb9258...
#
#                                        covariate_ids
# 0  [6aefddc9-e00e-495e-bb20-c564836405bc, 147a20a...
# 1             [d479df17-7be5-4618-9a14-cb189ea81c10]
# 2             [3ca907d6-0132-4610-a386-1f1f3c07a3c5]
# 3             [70f83dbd-953b-4884-b46e-be23deb230d4]
# 4  [ebd0c996-e91f-4434-bec3-458b057601be, 5b27eea...

# %%
api_key = os.environ["AZURE_OPENAI_API_KEY"]
api_base = os.environ["GRAPHRAG_API_BASE"]
api_version = os.environ["GRAPHRAG_API_VERSION"]
llm_model = os.environ["GRAPHRAG_LLM_MODEL"]
llm_deployment_name = os.environ["GRAPHRAG_LLM_DEPLOYMENT_NAME"]
embedding_model = os.environ["GRAPHRAG_EMBEDDING_MODEL"]
embedding_deployment_name = os.environ["GRAPHRAG_EMBEDDING_DEPLOYMENT_NAME"]
embedding_version = os.environ["GRAPHRAG_EMBEDDING_VERSION"]

llm = ChatOpenAI(
    api_key=api_key,
    model=llm_model,
    api_type=OpenaiApiType.AzureOpenAI,  # OpenaiApiType.OpenAI or OpenaiApiType.AzureOpenAI
    deployment_name=llm_deployment_name,
    max_retries=20,
    api_base=api_base,
    api_version=api_version,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

text_embedder = OpenAIEmbedding(
    api_key=api_key,
    api_base=api_base,
    api_type=OpenaiApiType.AzureOpenAI,
    model=embedding_model,
    deployment_name=embedding_deployment_name,
    max_retries=20,
    api_version=api_version,
)

# %% [markdown]
# ### Create local search context builder

# %%
context_builder = LocalSearchMixedContext(
    community_reports=reports,
    text_units=text_units,
    entities=entities,
    relationships=relationships,
    # if you did not run covariates during indexing, set this to None
    covariates=covariates,
    # covariates=None,
    entity_text_embeddings=description_embedding_store,
    embedding_vectorstore_key=EntityVectorStoreKey.ID,  # if the vectorstore uses entity title as ids, set this to EntityVectorStoreKey.TITLE
    text_embedder=text_embedder,
    token_encoder=token_encoder,
)

# %% [markdown]
# ### Create local search engine

# %%
# text_unit_prop: proportion of context window dedicated to related text units
# community_prop: proportion of context window dedicated to community reports.
# The remaining proportion is dedicated to entities and relationships. Sum of text_unit_prop and community_prop should be <= 1
# conversation_history_max_turns: maximum number of turns to include in the conversation history.
# conversation_history_user_turns_only: if True, only include user queries in the conversation history.
# top_k_mapped_entities: number of related entities to retrieve from the entity description embedding store.
# top_k_relationships: control the number of out-of-network relationships to pull into the context window.
# include_entity_rank: if True, include the entity rank in the entity table in the context window. Default entity rank = node degree.
# include_relationship_weight: if True, include the relationship weight in the context window.
# include_community_rank: if True, include the community rank in the context window.
# return_candidate_context: if True, return a set of dataframes containing all candidate entity/relationship/covariate records that
# could be relevant. Note that not all of these records will be included in the context window. The "in_context" column in these
# dataframes indicates whether the record is included in the context window.
# max_tokens: maximum number of tokens to use for the context window.


local_context_params = {
    "text_unit_prop": 0.5,
    "community_prop": 0.1,
    "conversation_history_max_turns": 5,
    "conversation_history_user_turns_only": True,
    "top_k_mapped_entities": 10,
    "top_k_relationships": 10,
    "include_entity_rank": True,
    "include_relationship_weight": True,
    "include_community_rank": False,
    "return_candidate_context": False,
    "embedding_vectorstore_key": EntityVectorStoreKey.ID,  # set this to EntityVectorStoreKey.TITLE if the vectorstore uses entity title as ids
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
}

llm_params = {
    "max_tokens": 2_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000=1500)
    "temperature": 0.0,
}

# %%
search_engine = LocalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %% [markdown]
# ### Run local search on sample queries

# %%
result = await search_engine.asearch("Tell me about Antler")
print(result.response)
# Out:
# # Antler: A Comprehensive Overview
#
# ## Introduction to Antler
#
# Antler is a global startup generator and early-stage venture capital firm that plays a pivotal role in the entrepreneurial ecosystem. The firm supports founders from the pre-seed, pre-team, and even pre-idea stages, emphasizing the importance of investor-founder fit. Antler provides a comprehensive suite of resources, including mentorship, networking, and first principles coaching, to help founders develop and validate their ideas [Data: Entities (136); Claims (199, 307); Relationships (975, 980)].
#
# ## Comprehensive Support System
#
# Antler's support system is designed to ensure that entrepreneurs have a solid foundation for growth. This includes a wide range of services such as resources, network, coaching, and mentoring. The firm’s emphasis on first principles coaching helps founders break down complex problems and rebuild them from the ground up, fostering innovation and long-term success [Data: Entities (136, 1136); Claims (199, 307); Relationships (975, 980)].
#
# ## Global Presence and Accessibility
#
# Antler's services are available in 25 cities worldwide, making it accessible to a diverse range of entrepreneurs. This global presence allows Antler to support founders from various regions, fostering a diverse and inclusive entrepreneurial ecosystem. The availability of Antler's services in multiple locations also facilitates networking and collaboration among entrepreneurs from different backgrounds [Data: Entities (1584); Claims (59, 327); Relationships (990)].
#
# ## Focus on Early-Stage Funding
#
# Specializing in pre-seed funding, Antler supports founders from the earliest stages of their entrepreneurial journey. This focus is crucial for startups as it helps them develop their ideas and products before seeking larger investments. Antler's dedication to pre-seed funding ensures that visionary individuals receive the financial backing and guidance they need to succeed [Data: Entities (147, 148, 149); Claims (60, 307); Relationships (978, 972, 973, 974)].
#
# ## Emphasis on Investor-Founder Fit
#
# Antler stresses the importance of investor-founder fit, ensuring that the alignment between the investor and the founder in terms of vision and working relationship is crucial for long-term success. This emphasis helps founders choose the right investors who share their values, leadership approach, and strategy. By building a curated investor list, founders can secure the necessary support for their ventures [Data: Entities (1135); Claims (202); Relationships (979)].
#
# ## Residency Programs and Startup Accelerators
#
# Antler offers residency programs and startup accelerators to support founders in developing their startups from the pre-seed, pre-team, and pre-idea stages. These programs provide mentorship, networking, and VC funding opportunities, helping entrepreneurs find co-founders and grow their businesses. The residency programs are designed to assist founders in navigating the complexities of starting and scaling a business [Data: Entities (1465, 1582); Claims (59, 326); Relationships (984, 989)].
#
# ## Mentorship and Networking Opportunities
#
# Antler provides valuable mentorship and networking opportunities to entrepreneurs, fostering innovation and collaboration within the entrepreneurial ecosystem. Through its mentorship programs, Antler aims to help emerging businesses navigate challenges and achieve growth. Networking opportunities offered by Antler enable startups to build relationships, connect with other entrepreneurs, and drive innovation [Data: Entities (136); Claims (199, 326); Relationships (987, 988, 983)].
#
# ## Support for D2C Brand Ideas
#
# Antler also supports entrepreneurs with direct-to-consumer (D2C) brand ideas, helping them develop and validate their concepts. This support includes resources, mentorship, and networking opportunities, ensuring that founders have the necessary tools to succeed in the competitive D2C market. Antler's focus on D2C brands highlights its commitment to supporting a diverse range of business models [Data: Entities (136); Relationships (985)].
#
# ## Fundraising Concierge Service
#
# To streamline the fundraising process, Antler has developed a fundraising concierge service designed to assist founders in raising funds. This service provides essential support and resources to help entrepreneurs secure the necessary capital for their ventures. By offering guidance on setting fundraising goals and crafting compelling investment memos, Antler helps founders stand out to investors [Data: Claims (199, 201); Relationships (981)].
#
# In summary, Antler is a significant player in the global entrepreneurial ecosystem, providing extensive support to early-stage startups through its comprehensive suite of services, global presence, and focus on investor-founder fit.

# %%
# result = await search_engine.asearch("Tell me about Antler")
# print(result.response)
# Out:
# # Antler: A Global Startup Generator and Early-Stage Venture Capital Firm
#
# Antler is a prominent global startup generator and early-stage venture capital firm that plays a crucial role in supporting founders from the pre-seed, pre-team, and even pre-idea stages. The firm is dedicated to helping visionary individuals build successful companies by providing extensive resources, mentorship, and financial backing [Data: Entities (136); Relationships (975, 978, 972, 973, 974)].
#
# ## Comprehensive Suite of Resources
#
# Antler offers a comprehensive suite of resources designed to assist entrepreneurs in developing and validating their ideas. These resources include mentorship, networking opportunities, and first principles coaching. The mentorship programs provide valuable guidance from experienced professionals, while networking opportunities help entrepreneurs build relationships that foster collaboration and innovation. First principles coaching helps founders break down complex problems and rebuild them from the ground up, ensuring a solid foundation for growth [Data: Entities (136, 1135, 1136); Relationships (987, 988, 980, 981)].
#
# ## Residency Programs and Startup Accelerators
#
# To further support founders, Antler offers residency programs and startup accelerators. These programs provide mentorship, networking, and venture capital funding opportunities, helping entrepreneurs find co-founders and grow their businesses. The residency programs are available in 25 cities around the world, making Antler's support accessible to a global audience [Data: Entities (1465, 1582, 1584); Relationships (984, 989, 990)].
#
# ## Support for D2C Brands
#
# Antler also focuses on supporting entrepreneurs with direct-to-consumer (D2C) brand ideas. This support includes resources, network, coaching, and mentoring, which are crucial for the development and success of D2C startups. By focusing on D2C brands, Antler helps entrepreneurs tap into a growing market segment and build successful businesses [Data: Entities (136); Relationships (985)].
#
# ## Emphasis on Investor-Founder Fit
#
# One of the key aspects of Antler's approach is the emphasis on investor-founder fit. The alignment between the investor and the founder in terms of vision and working relationship is crucial for long-term success. Antler ensures that founders receive the right support and guidance from investors who share their vision, fostering a productive and collaborative entrepreneurial ecosystem [Data: Entities (1135); Relationships (979)].
#
# ## Pre-Seed Funding and Support
#
# Antler specializes in providing resources and support for pre-seed funding. As a dedicated pre-seed firm, Antler focuses on nurturing startups by offering the necessary financial backing and guidance to help them grow and succeed in their early stages. This initial funding stage is crucial for startups, as it is often used to develop an idea or product before seeking larger investments [Data: Entities (147); Relationships (978, 972)].
#
# ## Global Reach and Accessibility
#
# Antler's services are available in 25 cities around the world, making its support accessible to a global audience. This extensive reach allows Antler to support a diverse range of entrepreneurs and foster innovation and collaboration across different regions. The global presence of Antler enhances its ability to connect founders with a wide network of resources and opportunities [Data: Entities (1584); Relationships (990)].
#
# In summary, Antler is a central entity in the global entrepreneurial ecosystem, providing extensive support to founders through a comprehensive suite of resources, residency programs, and a strong emphasis on investor-founder fit. Its global reach and focus on pre-seed funding make it a vital player in nurturing the next generation of successful startups.

# %% [markdown]
# #### Inspecting the context data used to generate the response

# %%
result.context_data["entities"].head()
# Out:
#      id             entity                                        description  \
# 0   136             ANTLER  ANTLER is a global startup generator and early...
# 1  1584             CITIES  25 locations around the world where Antler's s...
# 2  1582   ANTLER RESIDENCY  Antler residency offers mentorship, networking...
# 3   676         MENTORSHIP  MENTORSHIP: Antler offers mentorship opportuni...
# 4  1465  RESIDENCY PROGRAM  Programs offered by Antler to support founders...
#
#   number of relationships  in_context
# 0                      20        True
# 1                       1        True
# 2                       1        True
# 3                       4        True
# 4                       1        True

# %%
result.context_data["relationships"].head()
# Out:
#     id  source                         target  \
# 0  988  ANTLER                     NETWORKING
# 1  987  ANTLER                     MENTORSHIP
# 2  981  ANTLER  FUNDRAISING CONCIERGE SERVICE
# 3  971  ANTLER                UNICORN FOUNDER
# 4  972  ANTLER                       PRE-SEED
#
#                                          description weight rank links  \
# 0  Antler offers networking opportunities to help...    2.0   28     2
# 1  Antler offers mentorship opportunities for ent...    2.0   24     1
# 2  Antler developed and offers a fundraising conc...    2.0   22     1
# 3  Antler supports founders aiming to become unic...    1.0   21     1
# 4   Antler supports founders from the pre-seed stage    2.0   21     1
#
#    in_context
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True

# %%
result.context_data["reports"].head()
# Out:
#     id                                            title  \
# 0  231  Antler and its Global Entrepreneurial Ecosystem
# 1  231  Antler and its Global Entrepreneurial Ecosystem
#
#                                              content
# 0  # Antler and its Global Entrepreneurial Ecosys...
# 1  # Antler and its Global Entrepreneurial Ecosys...

# %%
result.context_data["sources"].head()
# Out:
#     id                                               text
# 0   85   like Antler that go well beyond the money. Wi...
# 1  124  + and Apple TV sprung up,\nNetflix knew it nee...
# 2   84  # How To Raise A Pre-Seed Round \n **_TLDR:_**...
# 3  125  idency](https://www.antler.co/)! The mentorshi...
# 4    6   unicorn disruption. There was a real market\n...

# %%
if "claims" in result.context_data:
    print(result.context_data["claims"].head())

# %% [markdown]
# ### Question Generation

# %% [markdown]
# This function takes a list of user queries and generates the next candidate questions.

# %%
question_generator = LocalQuestionGen(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
)

# %%
question_history = [
    "Tell me about Antler",
    "What is the best approach for early stage startups to raise capital?",
]
candidate_questions = await question_generator.agenerate(
    question_history=question_history, context_data=None, question_count=5
)
print(candidate_questions.response)
# Out:
# ['- How does Antler support founders in the pre-seed stage?', '- What resources does Antler provide to help entrepreneurs develop and validate their ideas?', "- How do Antler's residency programs assist entrepreneurs in finding co-founders and growing their businesses?", '- What is the importance of investor-founder fit according to Antler?', "- How does Antler's global reach benefit entrepreneurs?"]
